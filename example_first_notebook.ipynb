# %% [markdown]
# ### First Python Notebook
#
# Let's use this notebook to confirm that your Python environment is working correctly and that you can run code cells in VS Code.

# %% [markdown]
# ### A simple calculation
#
# Start with a short example using ordinary Python variables.

# %%
a = 2
b = 3
c = a + b

print(f"The value of c is {c}.")
# Out:
# The value of c is 5.

# %% [markdown]
# ### Working with NumPy arrays
#
# Next, repeat the same idea with NumPy arrays, which will be covered in greater detail later!

# %%
import numpy as np


a = np.array([1, 2, 3])
b = np.array([3, 5, 7])
c = a + b

print(f"The array c is {c}.")
# Out:
# The array c is [ 4  7 10].

# %%
import numpy as np
d = np.array([4,5,3])
e = np.array([6,7,8])
f = d + e
print(f"The array f is {f}.")
# Out:
# The array f is [10 12 11].

# %% [markdown]
# git config --global user.name "Sahi Jallipalli"
